# %% [markdown]
# <a href="https://colab.research.google.com/github/kerlasaitejaswi17-debug/ai-mentor-portfolio/blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"

# %%
# !pip install -q --upgrade crewai litellm google-generativeai google-genai

# %% [markdown]
# Runtime → Restart Session

# %% [markdown]
# np.float_ was removed in NumPy 2.0

# %% [markdown]
# Installation completes without red traceback.

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:22:16 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:22:16 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %% [markdown]
# Use Gemini through CrewAI/LiteLLM string format.

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: ca143042-68e4-4037-a4c5-4bde3e201f5d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 469df380-9386-438a-8456-dece6d60c158                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's a placement preparation brief for TCS Digital for B.Tech students:                                      │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │                                                                                                                 │
# │  *   **Online Assessment:** Consists of Verbal Ability, Logical Reasoning, Numerical Ability, followed by a     │
# │  dedicated Coding Section (usually 1-2 questions).                                                              │
# │  *   **Technical Interview (TR):** Focuses on core computer science subjects (DSA, OS, DBMS, OOPs), projects    │
# │  mentioned in the resume, and problem-solving skills.                                                           │
# │  *   **Managerial Interview (MR) (Optional):** May assess practical application of skills, teamwork, and        │
# │  ability to handle project scenarios.                                                                           │
# │  *   **HR Interview (HR):** Evaluates communication skills, cultural fit, career aspirations, and suitability   │
# │  for the company.                                                                                               │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │                                                                                                                 │
# │  *   **Core CS Fundamentals:** Strong understanding of Data Structures & Algorithms (DSA), Operating Systems,   │
# │  Database Management Systems (DBMS), and Object-Oriented Programming (OOPs) concepts.                           │
# │  *   **Programming Languages:** Proficiency in at least one language like Java, Python, or C++ is essential     │
# │  for the coding round and technical interviews.                                                                 │
# │  *   **Web Technologies (Basic):** Familiarity with HTML, CSS, JavaScript, and basic web development            │
# │  principles is often a plus, especially for full-stack roles.                                                   │
# │  *   **Cloud & Emerging Tech (Awareness):** Basic knowledge of cloud platforms (AWS, Azure, GCP), AI/ML         │
# │  concepts, or data analytics can be beneficial.                                                                 │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │                                                                                                                 │
# │  *   **Academic Performance:** Typically requires a minimum aggregate of 60% or 6.0 CGPA throughout 10th,       │
# │  12th, and B.Tech.                                                                                              │
# │  *   **Degree and Branches:** B.Tech/BE students from Computer Science, Information Technology, Electronics &   │
# │  Communication, Electrical Engineering, or related disciplines.                                                 │
# │  *   **No Active Backlogs:** Candidates must not have any active backlogs at the time of applying or joining.   │
# │  *   **Year of Passing:** Specific to the current or upcoming graduating batch (e.g., 2024 pass-outs).          │
# │  *   **Education Gap:** A maximum education gap of 1-2 years (with valid justification) might be permissible.   │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │                                                                                                                 │
# │  *   **Enhanced Coding Emphasis:** Increased focus on competitive programming skills and efficient              │
# │  problem-solving in the coding assessment.                                                                      │
# │  *   **Project-Centric Interviews:** Interviewers increasingly delve deep into candidates' projects, asking     │
# │  about technologies used, challenges faced, and personal contributions.                                         │
# │  *   **Demonstrable Skills:** Preference for candidates who can practically demonstrate their technical         │
# │  skills, rather than just theoretical knowledge.                                                                │
# │  *   **Digital Niche Focus:** TCS Digital roles specifically target students with higher aptitude and advanced  │
# │  technical knowledge suitable for specialized projects in emerging technologies.                                │
# │  *   **Focus on Solution Design:** Beyond just coding, interviewers look for candidates who can articulate      │
# │  their thought process and design efficient solutions.                                                          │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │                                                                                                                 │
# │  *   **Master DSA:** Practice Data Structures & Algorithms extensively on platforms like LeetCode, HackerRank,  │
# │  or GeeksforGeeks; aim for medium-level problems.                                                               │
# │  *   **Strengthen Core CS Subjects:** Thoroughly revise OOPs, OS, DBMS, and Computer Networks, as these form    │
# │  the backbone of technical interviews.                                                                          │
# │  *   **Build Relevant Projects:** Develop 1-2 significant projects using technologies of interest to showcase   │
# │  your practical skills and problem-solving ability.                                                             │
# │  *   **Practice Aptitude & Coding Tests:** Regularly solve quantitative aptitude, logical reasoning, verbal     │
# │  ability, and coding questions under timed conditions.                                                          │
# │  *   **Prepare for Interviews:** Practice explaining your projects, common HR questions, and mock technical     │
# │  interviews to build confidence and articulate answers clearly.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 1e017ae0-d960-42a3-8ced-8318836f1b64                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Dreaming of a high-impact tech career? TCS Digital offers a launchpad to innovate and excel in emerging        │
# │  technologies. This brief is your essential guide to navigating the selection process and securing your spot.   │
# │  Get ready to unlock your potential and build the future!                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The TCS Digital Hiring Journey                                                                          │
# │                                                                                                                 │
# │  TCS Digital's selection process is designed to identify top talent. Familiarize yourself with each stage:      │
# │                                                                                                                 │
# │  *   **Online Assessment:** Kicks off with Verbal Ability, Logical Reasoning, and Numerical Ability sections.   │
# │  This is followed by a crucial **Coding Section**, typically featuring 1-2 challenging problems.                │
# │  *   **Technical Interview (TR):** Expect deep dives into **core Computer Science subjects** (Data Structures   │
# │  & Algorithms, OS, DBMS, OOPs), thorough discussions on your **resume projects**, and practical                 │
# │  **problem-solving** scenarios.                                                                                 │
# │  *   **Managerial Interview (MR) (Optional):** This round may assess your ability to apply skills practically,  │
# │  work in teams, and handle real-world project situations.                                                       │
# │  *   **HR Interview (HR):** Focuses on evaluating your **communication skills**, cultural fit within TCS,       │
# │  career aspirations, and overall suitability for the company.                                                   │
# │                                                                                                                 │
# │  ### 2. Your Technical Foundation                                                                               │
# │                                                                                                                 │
# │  A strong technical base is non-negotiable for TCS Digital. Here’s what to focus on:                            │
# │                                                                                                                 │
# │  *   **Core CS Fundamentals:** Master **Data Structures & Algorithms (DSA)**, Operating Systems (OS), Database  │
# │  Management Systems (DBMS), and Object-Oriented Programming (OOPs) concepts.                                    │
# │  *   **Programming Languages:** Be highly proficient in at least one primary language like **Java, Python, or   │
# │  C++**. This is vital for both coding rounds and technical discussions.                                         │
# │  *   **Web Technologies (Basic):** A foundational understanding of HTML, CSS, JavaScript, and basic web         │
# │  development principles can be a significant advantage.                                                         │
# │  *   **Cloud & Emerging Tech (Awareness):** Basic knowledge of cloud platforms (AWS, Azure, GCP), AI/ML         │
# │  concepts, or data analytics demonstrates future readiness.                                                     │
# │                                                                                                                 │
# │  ### 3. Eligibility Essentials                                                                                  │
# │                                                                                                                 │
# │  Ensure you meet the basic criteria before applying:                                                            │
# │                                                                                                                 │
# │  *   **Academic Performance:** A minimum aggregate of **60% or 6.0 CGPA** is typically required across your     │
# │  10th, 12th, and B.Tech degrees.                                                                                │
# │  *   **Degree and Branches:** Open to B.Tech/BE students from Computer Science, Information Technology,         │
# │  Electronics & Communication, Electrical Engineering, or other related disciplines.                             │
# │  *   **No Active Backlogs:** Candidates must not have any active backlogs at the time of applying or joining.   │
# │  *   **Year of Passing:** Specific to the current or upcoming graduating batch (e.g., 2024 pass-outs).          │
# │  *   **Education Gap:** A maximum education gap of 1-2 years (with valid justification) might be permissible.   │
# │                                                                                                                 │
# │  ### 4. What TCS Digital Seeks                                                                                  │
# │                                                                                                                 │
# │  TCS Digital looks for candidates with an edge, particularly in these areas:                                    │
# │                                                                                                                 │
# │  *   **Enhanced Coding Emphasis:** A strong focus on **competitive programming skills** and the ability to      │
# │  devise efficient problem-solving strategies in coding assessments.                                             │
# │  *   **Project-Centric Interviews:** Interviewers will delve deep into your projects, scrutinizing              │
# │  technologies used, challenges faced, and your specific contributions.                                          │
# │  *   **Demonstrable Skills:** A preference for candidates who can **practically showcase their technical        │
# │  abilities**, moving beyond mere theoretical knowledge.                                                         │
# │  *   **Digital Niche Focus:** TCS Digital roles target individuals with higher aptitude and advanced technical  │
# │  knowledge, suitable for specialized projects in emerging technologies.                                         │
# │  *   **Focus on Solution Design:** Beyond just coding, interviewers value candidates who can articulate their   │
# │  thought process and **design efficient, scalable solutions**.                                                  │
# │                                                                                                                 │
# │  ### 5. Your Preparation Roadmap                                                                                │
# │                                                                                                                 │
# │  Strategic preparation is key to success. Follow these tips:                                                    │
# │                                                                                                                 │
# │  *   **Master DSA:** Practice Data Structures & Algorithms extensively on platforms like LeetCode, HackerRank,  │
# │  or GeeksforGeeks. Aim to confidently solve **medium-level problems**.                                          │
# │  *   **Strengthen Core CS Subjects:** Thoroughly revise **OOPs, OS, DBMS, and Computer Networks**. These        │
# │  subjects form the backbone of technical interviews.                                                            │
# │  *   **Build Relevant Projects:** Develop **1-2 significant projects** using technologies of interest. These    │
# │  are your best tools to showcase practical skills and problem-solving ability.                                  │
# │  *   **Practice Aptitude & Coding Tests:** Regularly solve quantitative aptitude, logical reasoning, verbal     │
# │  ability, and coding questions under **timed conditions** to build speed and accuracy.                          │
# │  *   **Prepare for Interviews:** Practice explaining your projects concisely, prepare for common HR questions,  │
# │  and conduct **mock technical interviews** to build confidence and articulate answers clearly.                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  TCS Digital is looking for bright minds eager to make an impact in the world of technology. Start your         │
# │  focused preparation today, hone your skills, and showcase your best self. Your future in cutting-edge          │
# │  technology awaits – seize this incredible opportunity!                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact tech career? TCS Digital offers a launchpad to innovate and excel in emerging technologies. This brief is your essential guide to navigating the selection process and securing your spot. Get ready to unlock your potential and build the future!
#
# ---
#
# ### 1. The TCS Digital Hiring Journey
#
# TCS Digital's selection process is designed to identify top talent. Familiarize yourself with each stage:
#
# *   **Online Assessment:** Kicks off with Verbal Ability, Logical Reasoning, and Numerical Ability sections. This is followed by a crucial **Coding Section**, typically featuring 1-2 challenging problems.
# *   **Technical Interview (TR):** Expect deep dives into **core Computer Science subjects** (Data Structures & Algorithms, OS, DBMS, OOPs), thorough discussions on your **resume projects**, and practical **problem-solving** scenarios.
# *   **Managerial Interview (MR) (Optional):** This round may assess your ability to apply skills practically, work in teams, and handle real-world project situations.
# *   **HR Interview (HR):** Focuses on evaluating your **communication skills**, cultural fit within TCS, career aspirations, and overall suitability for the company.
#
# ### 2. Your Technical Foundation
#
# A strong technical base is non-negotiable for TCS Digital. Here’s what to focus on:
#
# *   **Core CS Fundamentals:** Master **Data Structures & Algorithms (DSA)**, Operating Systems (OS), Database Management Systems (DBMS), and Object-Oriented Programming (OOPs) concepts.
# *   **Programming Languages:** Be highly proficient in at least one primary language like **Java, Python, or C++**. This is vital for both coding rounds and technical discussions.
# *   **Web Technologies (Basic):** A foundational understanding of HTML, CSS, JavaScript, and basic web development principles can be a significant advantage.
# *   **Cloud & Emerging Tech (Awareness):** Basic knowledge of cloud platforms (AWS, Azure, GCP), AI/ML concepts, or data analytics demonstrates future readiness.
#
# ### 3. Eligibility Essentials
#
# Ensure you meet the basic criteria before applying:
#
# *   **Academic Performance:** A minimum aggregate of **60% or 6.0 CGPA** is typically required across your 10th, 12th, and B.Tech degrees.
# *   **Degree and Branches:** Open to B.Tech/BE students from Computer Science, Information Technology, Electronics & Communication, Electrical Engineering, or other related disciplines.
# *   **No Active Backlogs:** Candidates must not have any active backlogs at the time of applying or joining.
# *   **Year of Passing:** Specific to the current or upcoming graduating batch (e.g., 2024 pass-outs).
# *   **Education Gap:** A maximum education gap of 1-2 years (with valid justification) might be permissible.
#
# ### 4. What TCS Digital Seeks
#
# TCS Digital looks for candidates with an edge, particularly in these areas:
#
# *   **Enhanced Coding Emphasis:** A strong focus on **competitive programming skills** and the ability to devise efficient problem-solving strategies in coding assessments.
# *   **Project-Centric Interviews:** Interviewers will delve deep into your projects, scrutinizing technologies used, challenges faced, and your specific contributions.
# *   **Demonstrable Skills:** A preference for candidates who can **practically showcase their technical abilities**, moving beyond mere theoretical knowledge.
# *   **Digital Niche Focus:** TCS Digital roles target individuals with higher aptitude and advanced technical knowledge, suitable for specialized projects in emerging technologies.
# *   **Focus on Solution Design:** Beyond just coding, interviewers value candidates who can articulate their thought process and **design efficient, scalable solutions**.
#
# ### 5. Your Preparation Roadmap
#
# Strategic preparation is key to success. Follow these tips:
#
# *   **Master DSA:** Practice Data Structures & Algorithms extensively on platforms like LeetCode, HackerRank, or GeeksforGeeks. Aim to confidently solve **medium-level problems**.
# *   **Strengthen Core CS Subjects:** Thoroughly revise **OOPs, OS, DBMS, and Computer Networks**. These subjects form the backbone of technical interviews.
# *   **Build Relevant Projects:** Develop **1-2 significant projects** using technologies of interest. These are your best tools to showcase practical skills and problem-solving ability.
# *   **Practice Aptitude & Coding Tests:** Regularly solve quantitative aptitude, logical reasoning, verbal ability, and coding questions under **timed conditions** to build speed and accuracy.
# *   **Prepare for Interviews:** Practice explaining your projects concisely, prepare for common HR questions, and conduct **mock technical interviews** to build confidence and articulate answers clearly.
#
# ---
#
# TCS Digital is looking for bright minds eager to make an impact in the world of technology. Start your focused preparation today, hone your skills, and showcase your best self. Your future in cutting-edge technology awaits – seize this incredible opportunity!

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 5009

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here's a placement preparation brief for TCS Digital for B.Tech students:
#
# ### Hiring Process
#
# *   **Online Assessment:** Consists of Verbal Ability, Logical Reasoning, Numerical Ability, followed by a dedicated Coding Section (usually 1-2 questions).
# *   **Technical Interview (TR):** Focuses on core computer science subjects (DSA, OS, DBMS, OOPs), projects mentioned in the resume, and problem-solving skills.
# *   **Managerial Interview (MR) (Optional):** May assess practical application of skills, teamwork, and ability to handle project scenarios.
# *   **HR Interview (HR):** Evaluates communication skills, cultural fit, career aspirations, and suitability for the company.
#
# ### Technical Stack
#
# *   **Core CS Fundamentals:** Strong understanding of Data Structures & Algorithms (DSA), Operatin
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact tech career? TCS Digital offers a launchpad to innovate and excel in emerging technologies. This brief is your essential guide to navigating the selection process and securing your spot. Get ready to unlock your potential and build the future!
#
# ---
#
# ### 1. The TCS Digital Hiring Journey
#
# TCS Digital's selection process is designed to identify top talent. Familiarize yourself with each stage:
#
# *   **Online Assessment:** Kicks off with Verbal Ability, Logical Reasoning, and Numerical Ability sections. This is followed by a crucial **Coding Section**, typically featuring 1-2 challenging problems.
# *   **Technical Interview (TR):** Expect deep dives into **core Computer Science subjects** (Data Structures & Algorithms, OS, DBMS, OO

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact tech career? TCS Digital offers a launchpad to innovate and excel in emerging technologies. This brief is your essential guide to navigating the selection process and securing your spot. Get ready to unlock your potential and build the future!
#
# ---
#
# ### 1. The TCS Digital Hiring Journey
#
# TCS Digital's selection process is designed to identify top talent. Familiarize yourself with each stage:
#
# *   **Online Assessment:** Kicks off with Verbal Ability, Logical Reasoning, and Numerical Ability sections. This is followed by a crucial **Coding Section**, typically featuring 1-2 challenging problems.
# *   **Technical Interview (TR):** Expect deep dives into **core Computer Science subjects** (Data Structures & Algorithms, OS, DBMS, OOPs), thorough discussions on your **resume projects**, and practical **problem-solving** scenarios.
# *   **Managerial Interview (MR) (Optional):** This round may assess your ability to apply skills practically, work in teams, and handle real-world project situations.
# *   **HR Interview (HR):** Focuses on evaluating your **communication skills**, cultural fit within TCS, career aspirations, and overall suitability for the company.
#
# ### 2. Your Technical Foundation
#
# A strong technical base is non-negotiable for TCS Digital. Here’s what to focus on:
#
# *   **Core CS Fundamentals:** Master **Data Structures & Algorithms (DSA)**, Operating Systems (OS), Database Management Systems (DBMS), and Object-Oriented Programming (OOPs) concepts.
# *   **Programming Languages:** Be highly proficient in at least one primary language like **Java, Python, or C++**. This is vital for both coding rounds and technical discussions.
# *   **Web Technologies (Basic):** A foundational understanding of HTML, CSS, JavaScript, and basic web development principles can be a significant advantage.
# *   **Cloud & Emerging Tech (Awareness):** Basic knowledge of cloud platforms (AWS, Azure, GCP), AI/ML concepts, or data an
