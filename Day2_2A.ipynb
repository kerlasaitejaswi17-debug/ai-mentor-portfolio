# %% [markdown]
# <a href="https://colab.research.google.com/github/kerlasaitejaswi17-debug/ai-mentor-portfolio/blob/main/Day2_2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 2 — Lab 2A: Six-Pattern Drills

# %% [markdown]
# Explain recursion for a placement interview.”
#
# Step 1 — Pattern 1: PERSONA
# Prompt
#
# "You are a senior placement coach at an Indian engineering college. You have trained 300 B.Tech CSE students for placement interviews at TCS, Infosys, and Wipro. A nervous 2nd-year student asks you what recursion is before a coding interview. Explain recursion in a simple, conversational, interview-oriented way with one example."
#
# Example Output
#
# Recursion means a function calling itself to solve a smaller version of the same problem. Think of it like opening a box and finding another smaller box inside until you finally reach the smallest one. That stopping point is called the base case.
#
# Example: factorial(5) = 5 × factorial(4). The function keeps calling itself until factorial(1).
#
# Self-Score
#
# 5/5
#
# Step 2 — Pattern 2: FEW-SHOT
# Prompt
#
# "Here are some placement-style explanations:
#
# Q: What is a loop?
# A: A loop repeats a block of code until a condition becomes false.
#
# Q: What is an array?
# A: A collection of elements stored in continuous memory locations.
#
# Q: What is recursion?
# A:"
#
# Example Output
#
# A function calling itself with a smaller problem until it reaches a stopping condition called the base case. Example: factorial and Fibonacci series.
#
# Self-Score
#
# 4/5
#
# Step 3 — Pattern 3: CHAIN-OF-THOUGHT
# Prompt
#
# "Explain recursion to a placement interview candidate. Think step by step before answering.
#
# Step 1: Define recursion in one sentence.
# Step 2: Explain the base case.
# Step 3: Give one code example.
# Step 4: Mention why interviewers ask recursion questions.
# Step 5: Summarize in 3 sentences."
#
# Example Output
# Step 1
#
# Recursion is a programming technique where a function calls itself.
#
# Step 2
#
# The base case stops the recursive calls and prevents infinite recursion.
#
# Step 3
# def factorial(n):
#     if n == 1:
#         return 1
#     return n * factorial(n-1)
# Step 4
#
# Interviewers use recursion questions to test problem-solving and logical thinking.
#
# Step 5
#
# Recursion breaks a large problem into smaller similar problems. Every recursive function must have a base case. Common examples are factorial, Fibonacci, and tree traversal.
#
# Self-Score
#
# 5/5
#
# Step 4 — Pattern 4: STRUCTURED OUTPUT
# Prompt
#
# "Explain recursion for placement interviews. Return ONLY valid JSON with this exact structure:
#
# {
# "definition": "",
# "analogy": "",
# "code_example": "",
# "common_mistake": "",
# "interview_question": ""
# }"
#
# Example Output
# {
#   "definition": "Recursion is when a function calls itself to solve a smaller version of a problem.",
#   "analogy": "Like standing between two mirrors where the same image repeats again and again.",
#   "code_example": "factorial(n) = n * factorial(n-1)",
#   "common_mistake": "Forgetting the base case causing infinite recursion.",
#   "interview_question": "What is the difference between recursion and iteration?"
# }
# Self-Score
#
# 5/5
#
# Step 5 — Pattern 5: SYSTEM PROMPT
# System Prompt
#
# "You are a placement trainer for B.Tech CSE students. Explain concepts in 60 words max using simple English and one example."
#
# User Prompt
#
# "Explain recursion."
#
# Example Output
#
# Recursion is when a function calls itself to solve smaller versions of the same problem. Every recursive function needs a base case to stop execution.
#
# Example: factorial(5) = 5 × factorial(4) × factorial(3)...
#
# Self-Score
#
# 4/5
#
# Step 6 — Pattern 6: PROMPT CHAINING
# Conversation 1 — Extract
# Prompt
#
# "List the 5 most important subtopics a placement student must know about recursion."
#
# Output
# Definition
# Base case
# Recursive calls
# Stack memory
# Difference between recursion and loops
# Conversation 2 — Expand
# Prompt
#
# "Explain these recursion subtopics for a B.Tech placement student:
#
# [paste topics]"
#
# Example Output
# Definition: Function calling itself
# Base case: Stops infinite calls
# Recursive call: Smaller subproblem
# Stack memory: Calls stored in stack
# Difference from loops: Recursion uses function calls
# Conversation 3 — Polish
# Prompt
#
# "Combine these explanations into one 80-word placement interview explanation."
#
# Example Output
#
# Recursion is a programming method where a function calls itself to solve smaller parts of a problem. Every recursive function needs a base case to stop execution; otherwise infinite recursion happens. Recursive calls are stored in stack memory. Recursion is useful for trees, factorials, and divide-and-conquer problems. Interviewers ask recursion questions to test logical thinking and problem decomposition.
#
# Practice Question: Write a recursive Fibonacci program.
#
# Self-Score
#
# 5/5
#
# Peer-Scoring Rubric
# Criterion	Score
# Clarity	2
# Context	2
# Specificity	2
# Format	2
# Verification	1
#
# Total: 9/10
