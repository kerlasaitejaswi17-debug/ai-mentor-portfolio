# %% [markdown]
# <a href="https://colab.research.google.com/github/kerlasaitejaswi17-debug/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the comprehensive range of skills needed for successful AI development and deployment, building from foundational to strategic:
#
# *   **Foundation (Layers 1 & 2):** Covers technical bedrock including **Data & Infrastructure** (data engineering, compute) and **Machine Learning Algorithms & Models** (core AI techniques, model development).
# *   **Application (Layer 3):** Focuses on **Domain Expertise & Problem Formulation**, translating real-world challenges into solvable AI problems and understanding context.
# *   **Responsibility (Layer 4):** Emphasizes **Ethics, Explainability & Responsibility**, ensuring AI systems are fair, transparent, accountable, and socially beneficial.
# *   **Leadership (Layer 5):** The apex, **Strategic Vision & Business Integration**, aligns AI initiatives with organizational goals to drive value and ensure overall business success.
